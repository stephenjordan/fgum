# %%
import re
import math

# %%
# Initialize the four separate lists you requested
k_list = []
D_list = []
threshold_list = []
uncertainty_list = []
threshmax_list = []
threshmin_list = []

# Regular expressions to catch the relevant lines in the text file
# Matches lines like: Executing with k=3, D=4...
kd_pattern = re.compile(r"Executing with k=(\d+),\s*D=(\d+)\.\.\.")
# Matches lines like: threshold appears to be at least 0.167055845293798 - 0.167055964503087
bounds_pattern = re.compile(r"threshold appears to be at least ([\d\.]+) - ([\d\.]+)")

# Open and parse the file
with open('de_results.txt', 'r') as file:
    current_k = None
    current_D = None
    
    for line in file:
        # Check if the line contains k and D
        kd_match = kd_pattern.search(line)
        if kd_match:
            current_k = int(kd_match.group(1))
            current_D = int(kd_match.group(2))
        
        # Check if the line contains the threshold bounds
        bounds_match = bounds_pattern.search(line)
        if bounds_match and current_k is not None and current_D is not None:
            lower_bound = float(bounds_match.group(1))
            upper_bound = float(bounds_match.group(2))
            
            # Compute threshold and uncertainty
            threshold = (lower_bound + upper_bound) / 2.0
            uncertainty = abs(upper_bound - lower_bound)
            
            # Append to the lists
            k_list.append(current_k)
            D_list.append(current_D)
            threshold_list.append(threshold)
            uncertainty_list.append(uncertainty)
            threshmax_list.append(upper_bound)
            threshmin_list.append(lower_bound)
            
            # Reset current k and D to ensure we don't duplicate data if the file formatting gets weird
            current_k = None
            current_D = None

# %%
def s(thresh):
    return 0.5+math.sqrt(thresh*(1.0-thresh))

# %%
print("k", "D", "threshmin", "threshmax", "threshold", "uncertainty","s_minimum","s_maximum", sep="\t")
for i in range(len(k_list)):
    print(f"{k_list[i]}\t{D_list[i]}\t{threshmin_list[i]:.6f}\t{threshmax_list[i]:.6f}\t{threshold_list[i]:.6f}\t{uncertainty_list[i]:.2e}\t{s(threshmin_list[i]):.6f}\t{s(threshmax_list[i]):.6f}")
# Out:
# k	D	threshmin	threshmax	threshold	uncertainty	s_minimum	s_maximum
# 3	4	0.167056	0.167056	0.167056	1.19e-07	0.873026	0.873026
# 3	5	0.113829	0.113829	0.113829	5.96e-08	0.817604	0.817604
# 3	6	0.084122	0.084122	0.084122	5.96e-08	0.777571	0.777571
# 3	7	0.065603	0.065603	0.065603	5.96e-08	0.747587	0.747587
# 3	8	0.053117	0.053117	0.053117	2.98e-08	0.724267	0.724267
# 4	5	0.153540	0.153540	0.153540	1.19e-07	0.860508	0.860508
# 4	6	0.116941	0.116941	0.116941	5.96e-08	0.821350	0.821350
# 4	7	0.093232	0.093232	0.093232	5.96e-08	0.790757	0.790757
# 4	8	0.076815	0.076815	0.076815	5.96e-08	0.766298	0.766298
# 5	6	0.137413	0.137413	0.137413	1.19e-07	0.844282	0.844283
# 5	7	0.110880	0.110880	0.110880	5.96e-08	0.813984	0.813984
# 5	8	0.092227	0.092227	0.092227	5.96e-08	0.789346	0.789346
# 6	7	0.123572	0.123572	0.123572	1.19e-07	0.829092	0.829092
# 6	8	0.103414	0.103414	0.103414	5.96e-08	0.804499	0.804499
# 7	8	0.112108	0.112108	0.112108	5.96e-08	0.815499	0.815499

# %%
print("k", "D", "s", sep="\t")
for i in range(len(k_list)):
    print(f"{k_list[i]}\t{D_list[i]}\t{s(threshmin_list[i]):.4f}")
# Out:
# k	D	s
# 3	4	0.8730
# 3	5	0.8176
# 3	6	0.7776
# 3	7	0.7476
# 3	8	0.7243
# 4	5	0.8605
# 4	6	0.8214
# 4	7	0.7908
# 4	8	0.7663
# 5	6	0.8443
# 5	7	0.8140
# 5	8	0.7893
# 6	7	0.8291
# 6	8	0.8045
# 7	8	0.8155
